# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO

import random 
import numpy as np 

def tirar_dado (numero_de_simulaciones):
    contar = 0
    
    for i in range(numero_de_simulaciones):
        
        dado1 = random.randint(1,6)
        dado2 = random.randint(1,6)
        suma = dado1 + dado2
        if suma > 7 or ( suma%2== 0):
            contar+=1 

    return contar/(numero_de_simulaciones)

print (tirar_dado(1000))
# Out:
# 0.666

# %% [markdown]
# ### Conclusión
# La probabilidad de obtener un número par o un número mayor a 7, al lanzar dos dados, será la indicada en el resultado de arriba.

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}

# %%
# TODO

import random
import numpy as np 

def agarrar_la_bola (bolsa):
    bolas = random.randint(0,59)
    return bolsa[bolas]

print (agarrar_la_bola(ball_box))

def tomar_5bolas(bolsa):
    cuenta = []
    for i in range(5):
        cuenta.append(agarrar_la_bola(bolsa))
    return cuenta
print(tomar_5bolas(ball_box))

def ejercicio2 (bolsa, simulaciones):
    contar1= 0 
    contar2 =0 
    for i in range(simulaciones):
        resultado = tomar_5bolas(bolsa)
        resultado = np.array(resultado)
        bolas_blancas = sum(resultado == "White")
        bolas_rojas = sum(resultado == "Red")   
        bolas_verdes = sum(resultado == "Green")

        if (bolas_blancas == 3) and (bolas_rojas == 2): 
            contar1+=1 
        if (bolas_rojas == 5) or (bolas_rojas==5) or (bolas_verdes == 5): 
            contar2+=1 
    return contar1/simulaciones , contar2/simulaciones

probabilidades = ejercicio2 (ball_box,1000)

print (probabilidades)
# Out:
# Red
# ['Green', 'White', 'Red', 'Green', 'Red']
# (0.005, 0.035)

# %% [markdown]
# ### Conclusión
# Finalmente tendremos que la probabilidad de que se escojan 3 bolas blancas y 2 rojas, y también la probabilidad de escogerlas todas del mismo color. Será la expresada al correr el código anterior.
